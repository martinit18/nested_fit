# %%
#from matplotlib.pyplot import * 
#from numpy import *
import nested_res_V4p5 as nr
import os

# %matplotlib inline
#%matplotlib widget
#%matplotlib notebook
# Out:
# ###########################################################
# #                                                         #
# #         WELCOME TO NESTED_FIT RESULT ANALYSIS           #
# #                                                         #
# #                                                         #
# # Start with                                              #
# # 'an=nested_res_V4p5.Analysis()'                         #
# # By default the current path is considered.              #
# #                                                         #
# # If you want analyze another path:                       #
# # 'an=nested_res_V4p5.Analysis(path="path")'              #
# #                                                         #
# # If you do not want to specify any path:                 #
# # 'an=nested_res.Analysis(path=None)'                     #
# #                                                         #
# # To reload the data in the present directory:            #
# # 'an.load_data()'                                        #
# # otherwise specific the path                             #
# # 'an.load_data(path="your path")'                        #
# #                                                         #
# # Uses the different functions                            #
# # 'an.function()', (ex: 'an.plot()')                      #
# #                                                         #
# # To see the available function tape                      #
# # 'an.' and then the 'tab' button                         #
# #                                                         #
# # To see the description of the different functions tape: #
# # 'an.function?'                                          #
# #                                                         #
# # For any problem write to trassinelli@insp.jussieu.fr    #
# ###########################################################
#
# Present version 4.5

# %%
# Define the present path
path = os.getcwd()

# %%
# Choose one of them
path = path+'/res_3gauss_bg'

# %%
# Load the nested output data
# The available parameters and other variables that can be plotted are listed
an=nr.Analysis(path=path)
# Out:
# Current path =  /Users/martino/Owncloud/CNRS/work/programs/nested_fit/actual_version_with_git/examples/jupyter_notebooks/res_3gauss_bg
# Available parameters : ['weight', 'lnlikelihood', 'bg', 'x01', 'x02', 'x03', 'x04', 'amp1', 'amp2', 'amp3', 'amp4', 'sigma']

# %%
# Plot the data with the best fit (parameters corresponding to the maximum value of the data) and residual
# Other choices are median and mean parameters values selectable with "typeof='mean'" and "typeof='median'"
an.plot(path=path)
# Out:
# 0 max
# nf_output_data_max.dat

# %%
# Plot the likelihood sampling 
an.plot_like()

# %%
# Plot the weights of nested sampling corresponding to w_n = Delta X_n L_n
an.plot_weights()

# %%
# Plot the parameter convergence
# Colored regions correspond to the high value of the weights
an.plot_par('x01')
# Out:
# Set par_number x01 to 3

# %%
# Plot one parameter histogram
# Red, yellow and green region correspond to 1,2,3 sigmas
an.histo('x01',bins=100,xmin=350,xmax=500)
# Out:
# Set par_number x01 to 3

# %%
# Plot one parameter interpolated histogram using getdist
an.histo_interp('x01',path=path)
# Out:
# WARNING:root:auto bandwidth for x01 very small or failed (h=0.0012952436580087685,N_eff=2570.2673295603827). Using fallback (h=0.023877345516002648)
# /Users/martino/Owncloud/CNRS/work/programs/nested_fit/actual_version_with_git/examples/jupyter_notebooks/res_3gauss_bg/nf_output_points.txt
# Removed no burn in

# %%
# Plot one parameter histogram
# Red, yellow and green region correspond to 1,2,3 sigmas
an.histo2D('x01','amp1',bins=200,xmin=350,xmax=500,ymin=0,ymax=300)
# Out:
# /Users/martino/lib/python/nested_res_V4p5.py:1345: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(log(histo2D_data68[::-1,]),interpolation='nearest',extent=extent,aspect='auto',cmap=rvb68)
# /Users/martino/lib/python/nested_res_V4p5.py:1346: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(log(histo2D_data95[::-1,]),interpolation='nearest',extent=extent,aspect='auto',cmap=rvb95)
# /Users/martino/lib/python/nested_res_V4p5.py:1347: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(log(histo2D_data99[::-1,]),interpolation='nearest',extent=extent,aspect='auto',cmap=rvb99)
# /Users/martino/lib/python/nested_res_V4p5.py:1348: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(log(histo2D_data_rest[::-1,]),interpolation='nearest',extent=extent,aspect='auto',cmap=rvb_rest)
# Set par_number x01 to 3
# Set par_number amp1 to 7

# %%
# Same with interpolation from getdist
an.histo2D_interp('x01','amp1',path=path)
# Out:
# /Users/martino/lib/python/nested_res_V4p5.py:1542: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# Triangle plot (from anesthetic) to have a look to all parameters at the same time
an.triangle_plot(['x01','x02'],path=path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Triangle plot (from getdist) to have a look to all parameters at the same time
# ----> 2 an.triangle_plot(['x01','x02'],path=path)
#
# File ~/lib/python/nested_res_V4p5.py:1576, in Analysis.triangle_plot(self, params, path)
#    1571 from anesthetic import read_chains, make_2d_axes
#    1573 self.path = path
# -> 1576 nested_samples = read_chains(path)
#    1577 fig, axes = make_2d_axes(params)
#    1578 nested_samples.plot_2d(axes)
#
# File /opt/homebrew/lib/python3.11/site-packages/anesthetic/read/chain.py:65, in read_chains(root, *args, **kwargs)
#      62         errors.append(str(read) + ": " + str(e))
#      64 errors = ["Could not find any compatible chains:"] + errors
# ---> 65 raise FileNotFoundError('\n'.join(errors))
#
# FileNotFoundError: Could not find any compatible chains:
# <function read_polychord at 0x298669d00>: /Users/martino/Owncloud/CNRS/work/programs/nested_fit/actual_version_with_git/examples/jupyter_notebooks/res_3gauss_bg_dead-birth.txt not found.
# <function read_multinest at 0x29866a200>: /Users/martino/Owncloud/CNRS/work/programs/nested_fit/actual_version_with_git/examples/jupyter_notebooks/res_3gauss_bgev.dat not found.
# <function read_cobaya at 0x29866a0c0>: /Users/martino/Owncloud/CNRS/work/programs/nested_fit/actual_version_with_git/examples/jupyter_notebooks/res_3gauss_bg.([0-9]+)\.txt not found.
# <function read_ultranest at 0x29866a3e0>: [Errno 2] No such file or directory: '/Users/martino/Owncloud/CNRS/work/programs/nested_fit/actual_version_with_git/examples/jupyter_notebooks/res_3gauss_bg/info/results.json'
# <function read_nestedfit at 0x29866a5c0>: /Users/martino/Owncloud/CNRS/work/programs/nested_fit/actual_version_with_git/examples/jupyter_notebooks/res_3gauss_bg/nf_output_diag.dat not found.
# <function read_getdist at 0x29866a020>: /Users/martino/Owncloud/CNRS/work/programs/nested_fit/actual_version_with_git/examples/jupyter_notebooks/res_3gauss_bg((_|.)([0-9]+)|)\.txt not found.
